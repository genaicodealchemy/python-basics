# %% [markdown]
# <a href="https://colab.research.google.com/github/genaicodealchemy/python-basics/blob/main/Sets_and_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sets

# %%
## Sets are identified the items presents in curly braces {}

# %%
s = {1,2,3,4,5}
type(s)
# Out:
# set

# %%
s1 = {1,2,3,3,4,5,5,6}
type(s)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
l = [1,2,2,3,4,6,7,7]
se = set(l)
print(se)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
len(se)
# Out:
# 6

# %%
## sets are mutiable
# add function
se.add(10)
se
# Out:
# {1, 2, 3, 4, 6, 7, 10}

# %%
# remove function
se.remove(3)
se
# Out:
# {1, 2, 4, 6, 7, 10}

# %%
print(se)
print(s)
# Out:
# {1, 2, 4, 6, 7, 10}
# {1, 2, 3, 4, 5}

# %%
#union function
se.union(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 10}

# %%
# intersection functon
se.intersection(s)
# Out:
# {1, 2, 4}

# %%
# difference fuction
se.difference(s)
# Out:
# {6, 7, 10}

# %%
se - s
# Out:
# {6, 7, 10}

# %%
s - se
# Out:
# {3, 5}

# %% [markdown]
# Dictionary

# %%
d = {}
d1 = dict()
print(type(d))
# Out:
# <class 'dict'>

# %%
d = {'one':1, 'two':2, 'three':3, 4: 'four'}
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four'}

# %%
#how to add the values in a dics
d[5] = 'five'
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 5: 'five'}

# %%
d[6] = ['six', 'SIX']
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 5: 'five', 6: ['six', 'SIX']}

# %%
d[5] = 'FIVE'
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 5: 'FIVE', 6: ['six', 'SIX']}

# %%
## dict are collection of keys and values
## keys can be of two datatypes numeric and string
## values can be of any datatype
## there cannot be duplicate entries for a single key

# %%
# keys() function
d.keys()
# Out:
# dict_keys(['one', 'two', 'three', 4, 5, 6])

# %%
#values() function
d.values()
# Out:
# dict_values([1, 2, 3, 'four', 'FIVE', ['six', 'SIX']])

# %%
# items(0) function, results will be list of tuples
d.items()
# Out:
# dict_items([('one', 1), ('two', 2), ('three', 3), (4, 'four'), (5, 'FIVE'), (6, ['six', 'SIX'])])

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 4: 'four', 5: 'FIVE', 6: ['six', 'SIX']}

# %%
d[4]
# Out:
# 'four'

# %%
d[5]
# Out:
# 'FIVE'

# %%
#what if we try to extract the elements which is not present?
d[7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2044635059.py in <cell line: 0>()
#       1 #what if we try to extract the elements which is not present?
# ----> 2 d[7]
#
# KeyError: 7

# %%
# to avoid above error we can try in different way
d.get(7,0)
# Out:
# 0

# %%
d.get(5,0)
# Out:
# 'FIVE'

# %% [markdown]
# String

# %%
s = 'Hello'
type(s)
# Out:
# str

# %%
s.lower()
# Out:
# 'hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s
# Out:
# 'Hello'

# %%
s = s.upper()
s
# Out:
# 'HELLO'

# %%
s.capitalize()
# Out:
# 'Hello'

# %%
s[0]
# Out:
# 'H'

# %%
s[-2]
# Out:
# 'L'

# %%
s[0:3]
# Out:
# 'HEL'

# %%
s.isdigit()
# Out:
# False

# %%
## activity
## create a dictionary with a list of subjects and corresponding marks in each subjects
## Create a set of marks
## string play aroundwith all the function s as part of the string
