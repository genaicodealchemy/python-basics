# %% [markdown]
# <a href="https://colab.research.google.com/github/genaicodealchemy/python-basics/blob/main/pandas_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Null values in a datafram
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
pd.DataFrame([[201,'Male',34,None,None]],columns=list(df.columns))
# Out:
#    CustomerID Gender  Age Annual Income (k$) Spending Score (1-100)
# 0         201   Male   34               None                   None

# %%
# How to add two dataframes - concat function
df1 = pd.concat([df, pd.DataFrame([[201,'Male',34,None,None]],columns=list(df.columns))])
df1.shape
# Out:
# (201, 5)

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Handling Null values
df = df.dropna()

# %%
# Data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              201 non-null    int64
#  1   Gender                  201 non-null    object
#  2   Age                     201 non-null    int64
#  3   Annual Income (k$)      200 non-null    object
#  4   Spending Score (1-100)  200 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 9.4+ KB

# %%
pd.DataFrame([[201,'Male',34,None,None]],columns=list(df.columns)).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              1 non-null      int64
#  1   Gender                  1 non-null      object
#  2   Age                     1 non-null      int64
#  3   Annual Income (k$)      0 non-null      object
#  4   Spending Score (1-100)  0 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 172.0+ bytes

# %%
# Sorting the Dataframe
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df['Annual Income (k$)'].min()
# Out:
# 15

# %%
df['Spending Score (1-100)'].min()
# Out:
# 1

# %%
# sorting datafram in assending order
df.sort_values(by='Spending Score (1-100)', ascending=True)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 156         157    Male   37                  78                       1
# 158         159    Male   34                  78                       1
# 8             9    Male   64                  19                       3
# 30           31    Male   60                  30                       4
# 32           33    Male   53                  33                       4
# ..          ...     ...  ...                 ...                     ...
# 167         168  Female   33                  86                      95
# 185         186    Male   30                  99                      97
# 145         146    Male   28                  77                      97
# 19           20  Female   35                  23                      98
# 11           12  Female   35                  19                      99
#
# [200 rows x 5 columns]

# %%
df.sort_values(by='Spending Score (1-100)', ascending=False)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 11           12  Female   35                  19                      99
# 19           20  Female   35                  23                      98
# 145         146    Male   28                  77                      97
# 185         186    Male   30                  99                      97
# 167         168  Female   33                  86                      95
# ..          ...     ...  ...                 ...                     ...
# 30           31    Male   60                  30                       4
# 32           33    Male   53                  33                       4
# 8             9    Male   64                  19                       3
# 156         157    Male   37                  78                       1
# 158         159    Male   34                  78                       1
#
# [200 rows x 5 columns]

# %%
df.sort_values(by=['Annual Income (k$)','Spending Score (1-100)'], ascending=True)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Sorting on colunm
# One in ascending and the other in descending

df.sort_values(by=['Annual Income (k$)', 'Spending Score (1-100)'],ascending=False)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 199         200    Male   30                 137                      83
# 198         199    Male   32                 137                      18
# 197         198    Male   32                 126                      74
# 196         197  Female   45                 126                      28
# 195         196  Female   35                 120                      79
# ..          ...     ...  ...                 ...                     ...
# 4             5  Female   31                  17                      40
# 3             4  Female   23                  16                      77
# 2             3  Female   20                  16                       6
# 1             2    Male   21                  15                      81
# 0             1    Male   19                  15                      39
#
# [200 rows x 5 columns]

# %% [markdown]
# Merging two dataframes
