# %% [markdown]
# <a href="https://colab.research.google.com/github/genaicodealchemy/python-basics/blob/main/fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("print hello")
# Out:
# print hello

# %% [markdown]
# ## Python fundamentals and variable

# %%
number = 5500

# %%
number
# Out:
# 5500

# %%
# rules for creating a variable
# 1 a variable name should always start with character
# 2 there should be any special char in the name
#    ex roll_num
# variable name should not be keyword (ex print , if, else, for etc...)
# 4. it is preferable if your variable is in lower case ex: number / Number
# 5. Variable name should be meaningful

# %%
# Data Types
# 1 int
# 2 float
# 3 string
# 4 boolean

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
b = 1.2

# %%
type(b)
# Out:
# float

# %%
name = 'Akash'

# %%
type(name)
# Out:
# str

# %%
response = True
response2 = False
type(response)
type(response2)
# Out:
# bool

# %%
# Type casting: converting one data type to another
# int -> float
# float -> int (not vice versa)
# int -> strbool -> str (not vice versa)

# %%
a = 11
b = float(a)

# %%
b
# Out:
# 11.0

# %%
a = 12.9
b = int(a)

# %%
b
# Out:
# 12

# %%
a = 123
t = str(a)
t
# Out:
# '123'

# %%
b = True
t = str(b)
t
# Out:
# 'True'

# %%
b = 'aayush'
t = bool(b)
t
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(0)
# Out:
# False
